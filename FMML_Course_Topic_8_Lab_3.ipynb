# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayesha09988/FMMI-LAB-MODULES/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 04:38:48--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M  90.7MB/s    in 0.8s
#
# 2024-03-31 04:38:49 (90.7 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 21434  1802.06768v2  Creation of the information systems and tools ...    cs
# 4835   1601.06602v3  We present a novel algorithm for anomaly detec...    cs
# 7745   1803.01113v1  Distributed Stochastic Gradient Descent (SGD) ...  stat
# 8245    1409.4127v2  Unconstrained video recognition and Deep Convo...    cs
# 6601   1703.10622v2  In this paper we first identify a basic limita...  stat
# ...             ...                                                ...   ...
# 12921  1711.05825v2  Approximate Bayesian computation (ABC) and syn...  stat
# 32006   0910.4683v2  We study the problem of online regression. We ...    cs
# 34150   1405.6667v1  This paper addresses the task of user gender c...    cs
# 29125  1708.04896v2  In this paper, we introduce Random Erasing, a ...    cs
# 22557  1611.07460v1  We present the Wright-Fisher Indian buffet pro...  stat
#
#                                                    title  year  \
# 21434  Design and software implementation of subsyste...  2018
# 4835   Expected Similarity Estimation for Large-Scale...  2016
# 7745   Slow and Stale Gradients Can Win the Race: Err...  2018
# 8245   Transfer Learning for Video Recognition with S...  2014
# 6601   Diving into the shallows: a computational pers...  2017
# ...                                                  ...   ...
# 12921                  Bootstrapped synthetic likelihood  2017
# 32006             Competing with Gaussian linear experts  2009
# 34150  Inferring gender of a Twitter user using celeb...  2014
# 29125                   Random Erasing Data Augmentation  2017
# 22557   Poisson Random Fields for Dynamic Feature Models  2016
#
#                                                 keywords
# 21434  [information, scientific, development, directi...
# 4835   [algorithm, detection, similarity, estimation,...
# 7745   [distributed, stochastic, synchronous, asynchr...
# 8245   [unconstrained, recognition, convolution, reco...
# 6601   [limitation, optimization, conjunctions, prope...
# ...                                                  ...
# 12921  [approximate, computation, synthetic, likeliho...
# 32006  [regression, theoretical, regression, assumpti...
# 34150  [addresses, classification, application, autom...
# 29125  [introduce, augmentation, convolutional, recta...
# 22557  [probabilistic, dependent, generated, nonparam...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 21434    [information, scientific, development, directi...
# 4835     [algorithm, detection, similarity, estimation,...
# 7745     [distributed, stochastic, synchronous, asynchr...
# 8245     [unconstrained, recognition, convolution, reco...
# 6601     [limitation, optimization, conjunctions, prope...
#                                ...
# 22066    [theoretical, empirical, asymmetry, contaminat...
# 8982     [autonomous, locations, transparency, interfac...
# 4660     [dynamical, predictions, ubiquitous, engineeri...
# 4383     [performance, improving, technology, limitatio...
# 6294     [capacities, practitioners, distributed, compu...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8838 words.
# Out of those 4565 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="31d60659-c2b6-4ae2-8d9e-77a8b9d94c65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("31d60659-c2b6-4ae2-8d9e-77a8b9d94c65")) {                    Plotly.newPlot(                        "31d60659-c2b6-4ae2-8d9e-77a8b9d94c65",                        [{"x":["considered","formalisation","formulation","evolution","researcher","theoretical","principles","scientific","conditions","perspective","developing","functional","information","scientist","community","directions","ontological","implementation","subsystem","representation","knowledge","developed","interaction","personalized","practical","publications","collective","synthesis","environment","workstation","intensive","components","subsystems","development","approaches","magnitude","furthermore","formulated","predictions","different","adaptation","detection","assumption","embedding","underlying","algorithm","reproducing","demonstrate","algorithms","efficiently","similarity","streaming","methodologies","distribution","estimator","estimation","adversely","convergence","staleness","asynchronous","straggler","characterization","exponential","gradients","considers","assumptions","stochastic","synchronous","alleviate","analyzing","stragglers","distributed","annotated","convolution","recognizer","difficult","performance","convolutional","recognizers","correlation","therefore","preliminary","resultant","important","significant","researches","parameters","parameter","generalizability","unconstrained","selection","consuming","applicability","experiments","recognition","heuristic","available","instances","properties","obtaining","overfitting","shortcoming","conjunctions","inference","systematic","reachable","concentrating","approximately","algorithmic","iterations","dimensional","optimized","demonstrates","drastically","limitation","understood","optimization","iteration","literature","introduce","injecting","polynomial","complement","improvements","eigenvectors","approximation","sometimes","inexpensive","statistical","computation","phenomena","approximating","particular","preconditioning","computational","translates","consistently","approximate","intuition","traditional","aggressive","comparison","imageboards","anonymous","automatic","communities","behaviour","expression","aggression","auxiliary","extraordinary","regularization","maximizing","depending","classification","probability","challenging","outperforming","correspond","counterparts","explicitly","adversarial","discrimination","generative","discriminative","supervised","classifiers","unobserved","significantly","procedure","unsupervised","segmentation","navigation","contribute","procedural","contribution","automotive","realistic","variability","applications","annotations","evaluation","architectures","physically","efficiency","resulting","introspection","synthetic","departure","autonomous","rendering","generation","application","observations","estimating","marginals","maximization","improvement","estimates","likelihood"],"y":[131,2,82,71,2,151,32,31,127,73,61,46,720,4,64,50,4,126,3,361,354,206,97,21,138,4,20,47,127,2,31,103,4,146,415,48,173,36,75,681,63,351,66,109,124,830,14,534,591,169,160,17,18,231,30,220,5,131,1,8,0,28,45,39,29,68,120,4,26,53,0,95,68,50,7,156,864,383,5,81,152,49,10,341,236,9,259,130,7,22,158,33,39,621,361,67,274,106,211,41,20,5,2,171,39,2,1,36,39,19,191,40,67,15,24,30,335,36,123,324,5,60,24,99,8,126,23,3,146,146,30,21,281,3,285,4,44,106,20,180,4,139,2,5,187,22,31,48,2,27,2,92,37,34,528,177,290,23,25,20,64,111,17,113,83,183,111,9,277,116,126,185,29,33,5,73,6,54,27,431,68,275,104,6,164,145,2,119,1,68,19,127,248,68,63,5,24,146,84,64],"type":"bar"},{"x":["considered","formalisation","formulation","evolution","r ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4565,), (4565, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.8

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Unitary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Operators</span> <span style=''>with</span> <span style=''>Help</span> <span style=''>From</span> <span style=''>u(n)</span> <br/><br/><span style=''>A</span> <span style=''>major</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenge</span> <span style=''>in</span> <span style=''>the</span> <span style=''>training</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>recurrent</span> <span style=''>neural</span> <span style=''>networks</span> <span style=''>is</span> <span style=''>the</span> <span style=''>so</span> <span style=''>called</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>vanishing</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exploding</span> <span style=''>gradient</span> <span style=''>problem</span> <span style=''>The</span> <span style=''>use</span> <span style=''>of</span> <span style=''>a</span> <span style=''>norm</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>preserving</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>transition</span> <span style=''>operator</span> <span style=''>can</span> <span style=''>address</span> <span style=''>this</span> <span style=''>issue</span> <span style=''>but</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrization</span> <span style=''>is</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>challenging</span> <span style=''>In</span> <span style=''>this</span> <span style=''>work</span> <span style=''>we</span> <span style=''>focus</span> <span style=''>on</span> <span style=''>unitary</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>operators</span> <span style=''>and</span> <span style=''>describe</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrization</span> <span style=''>using</span> <span style=''>the</span> <span style=''>Lie</span> <span style=''>algebra</span> <span style=''>mathfraku(n)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>the</span> <span style=''>Lie</span> <span style=''>group</span> <span style=''>U(n)</span> <span style=''>of</span> <span style=''>n</span> <span style=''>times</span> <span style=''>n</span> <span style=''>unitary</span> <span style=''>matrices</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponential</span> <span style=''>map</span> <span style=''>provides</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correspondence</span> <span style=''>between</span> <span style=''>these</span> <span style=''>spaces</span> <span style=''>and</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>define</span> <span style=''>a</span> <span style=''>unitary</span> <span style=''>matrix</span> <span style=''>using</span> <span style=''>n2</span> <span style=''>real</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficients</span> <span style=''>relative</span> <span style=''>to</span> <span style=''>a</span> <span style=''>basis</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Lie</span> <span style=''>algebra</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametrization</span> <span style=''>is</span> <span style=''>closed</span> <span style=''>under</span> <span style=''>additive</span> <span style=''>updates</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficients</span> <span style=''>and</span> <span style=''>thus</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>simple</span> <span style=''>space</span> <span style=''>in</span> <span style=''>which</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>On</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>aspect</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6363636363636364);'>nonnegative</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.339622641509434);'>factorization</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style=''>provides</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3601694915254238);'>theoretical</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>explanation</span> <span style=''>on</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>aspect</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6363636363636364);'>nonnegative</span> <span style=''>matrix</span> <span style='background-color:rgba(255, 0, 0, 0.339622641509434);'>factorization</span> <span style=''>(NMF)</span> <span style=''>We</span> <span style=''>prove</span> <span style=''>that</span> <span style=''>even</span> <span style=''>without</span> <span style=''>imposing</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>orthogonality</span> <span style=''>nor</span> <span style=''>sparsity</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>constraint</span> <span style=''>on</span> <span style=''>the</span> <span style=''>basis</span> <span style=''>andor</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficient</span> <span style=''>matrix</span> <span style=''>NMF</span> <span style=''>still</span> <span style=''>can</span> <span style=''>give</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>results</span> <span style=''>thus</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>providing</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3601694915254238);'>theoretical</span> <span style=''>support</span> <span style=''>for</span> <span style=''>many</span> <span style=''>works</span> <span style=''>eg</span> <span style=''>Xu</span> <span style=''>et</span> <span style=''>al</span> <span style=''>1</span> <span style=''>and</span> <span style=''>Kim</span> <span style=''>et</span> <span style=''>al</span> <span style=''>2</span> <span style=''>that</span> <span style=''>show</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3333333333333333);'>superiority</span> <span style=''>of</span> <span style=''>the</span> <span style=''>standard</span> <span style=''>NMF</span> <span style=''>as</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style=''>method</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Learning</span> <span style=''>Time</span> <span style=''>Series</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Detection</span> <span style=''>Models</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Temporally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Imprecise</span> <span style=''>Labels</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>consider</span> <span style=''>a</span> <span style=''>new</span> <span style=''>low</span> <span style=''>quality</span> <span style=''>label</span> <span style=''>learning</span> <span style=''>problem</span> <span style=''>learning</span> <span style=''>time</span> <span style=''>series</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>detection</span> <span style=''>models</span> <span style=''>from</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>temporally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imprecise</span> <span style=''>labels</span> <span style=''>In</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>the</span> <span style=''>data</span> <span style=''>consist</span> <span style=''>of</span> <span style=''>a</span> <span style=''>set</span> <span style=''>of</span> <span style=''>input</span> <span style=''>time</span> <span style=''>series</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>supervision</span> <span style=''>is</span> <span style=''>provided</span> <span style=''>by</span> <span style=''>a</span> <span style=''>sequence</span> <span style=''>of</span> <span style=''>noisy</span> <span style=''>time</span> <span style=''>stamps</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>corresponding</span> <span style=''>to</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occurrence</span> <span style=''>of</span> <span style=''>positive</span> <span style=''>class</span> <span style=''>events</span> <span style=''>Such</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>temporally</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>imprecise</span> <span style=''>labels</span> <span style=''>commonly</span> <span style=''>occur</span> <span style=''>in</span> <span style=''>areas</span> <span style=''>like</span> <span style=''>mobile</span> <span style=''>health</span> <span style=''>research</span> <span style=''>where</span> <span style=''>human</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>annotators</span> <span style=''>are</span> <span style=''>tasked</span> <span style=''>with</span> <span style=''>labeling</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>occurrence</span> <span style=''>of</span> <span style=''>very</span> <span style=''>short</span> <span style=''>duration</span> <span style=''>events</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>general</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>that</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>accommodate</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>different</span> <span style=''>base</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classifiers</span> <span style=''>and</span> <span style=''>noise</span> <span style=''>models</span> <span style=''>We</span> <span style=''>present</span> <span style=''>results</span> <span style=''>on</span> <span style=''>real</span> <span style=''>mobile</span> <span style=''>health</span> <span style=''>data</span> <span style=''>showing</span> <span style=''>that</span> <span style=''>the</span> <span style=''> ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	evaluation (0.09793447293447294)
# 	knowledge (0.12606837606837606)
# 	segmentation (0.06588319088319089)
# 	architecture (0.08831908831908832)
# 	challenging (0.10327635327635327)
# 	experimental (0.14423076923076922)
# 	detection (0.125)
# 	information (0.2564102564102564)
# 	recognition (0.12856125356125356)
# 	convolutional (0.1363960113960114)
#
# Some Statistics words are:
# 	estimation (0.16164658634538154)
# 	variables (0.13654618473895583)
# 	stochastic (0.13453815261044177)
# 	distribution (0.18072289156626506)
# 	theoretical (0.16114457831325302)
# 	statistical (0.16415662650602408)
# 	algorithm (0.41164658634538154)
# 	dimensional (0.19477911646586346)
# 	inference (0.19678714859437751)
# 	regression (0.18825301204819278)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b7030860-a122-4090-89be-1c5671b71bf4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b7030860-a122-4090-89be-1c5671b71bf4")) {                    Plotly.newPlot(                        "b7030860-a122-4090-89be-1c5671b71bf4",                        [{"x":["considered","formalisation","formulation","evolution","researcher","theoretical","principles","scientific","conditions","perspective","developing","functional","information","scientist","community","directions","ontological","implementation","subsystem","representation","knowledge","developed","interaction","personalized","practical","publications","collective","synthesis","environment","workstation","intensive","components","subsystems","development","approaches","magnitude","furthermore","formulated","predictions","different","adaptation","detection","assumption","embedding","underlying","algorithm","reproducing","demonstrate","algorithms","efficiently","similarity","streaming","methodologies","distribution","estimator","estimation","adversely","convergence","staleness","asynchronous","straggler","characterization","exponential","gradients","considers","assumptions","stochastic","synchronous","alleviate","analyzing","stragglers","distributed","annotated","convolution","recognizer","difficult","performance","convolutional","recognizers","correlation","therefore","preliminary","resultant","important","significant","researches","parameters","parameter","generalizability","unconstrained","selection","consuming","applicability","experiments","recognition","heuristic","available","instances","properties","obtaining","overfitting","shortcoming","conjunctions","inference","systematic","reachable","concentrating","approximately","algorithmic","iterations","dimensional","optimized","demonstrates","drastically","limitation","understood","optimization","iteration","literature","introduce","injecting","polynomial","complement","improvements","eigenvectors","approximation","sometimes","inexpensive","statistical","computation","phenomena","approximating","particular","preconditioning","computational","translates","consistently","approximate","intuition","traditional","aggressive","comparison","imageboards","anonymous","automatic","communities","behaviour","expression","aggression","auxiliary","extraordinary","regularization","maximizing","depending","classification","probability","challenging","outperforming","correspond","counterparts","explicitly","adversarial","discrimination","generative","discriminative","supervised","classifiers","unobserved","significantly","procedure","unsupervised","segmentation","navigation","contribute","procedural","contribution","automotive","realistic","variability","applications","annotations","evaluation","architectures","physically","efficiency","resulting","introspection","synthetic","departure","autonomous","rendering","generation","application","observations","estimating","marginals","maximization","improvement","estimates","likelihood","structure","incorporates","technique","formulate","dimensions","demonstrated","surrogate","regularized","optimizer","direction","instability","effectively","addresses","normalized","fluctuations","optimizers","asynchrony","communication","constraints","introducing","centralized","empirically","mitigates","accumulated","normalization","quantized","architecture","overlapping","filtering","nonparametric","minimizing","determined","generalizes","densities","arbitrarily","functions","conditional","combinations","outperforms","diversified","continuous","generated","introduces","nonlinear","variables","manifolds","occlusions","background","riemannian","inaccurate","initially","prominent","deformations","statistics"," ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	straggler
# 	stragglers
# 	diversified
# 	portfolios
# 	unavoidably
# 	autocorrelation
# 	eigendecomposition
# 	hypernetworks
# 	penalizing
# 	safeguard
# 	emphmulti
# 	nonparanormal
# 	subpopulation
# 	discriminated
# 	unbiasedness
# 	economists
# 	bisection
# 	frequentist
# 	lucrative
# 	transplantation
# Some words which never appear in Statistics papers:
# 	formalisation
# 	ontological
# 	subsystem
# 	workstation
# 	subsystems
# 	recognizer
# 	recognizers
# 	imageboards
# 	extraordinary
# 	introspection
# 	occlusions
# 	attentions
# 	possession
# 	necessitates
# 	neighbouring
# 	annihilation
# 	repairing
# 	dialogues
# 	sentimental
# 	conveying

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.063256241384592e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7416666666666667
